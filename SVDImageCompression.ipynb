# %% [markdown]
# <a href="https://colab.research.google.com/github/AvaCook/cs315/blob/main/SVDImageCompression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize']=[10,8]

# %%
A=imread('saturn.jpg')
X=np.mean(A,-1);

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img=plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=False)
S=np.diag(S)

# %%
k=10
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=15
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=20
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=30
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()

# %%
k=40
Xapprox=U[:,:k] @ S[0:k,:k] @ VT[:k,:]
plt.figure(1)
img=plt.imshow(Xapprox)
img.set_cmap('gray')
plt.axis('off')
plt.title('k = '+str(k))
plt.show()
